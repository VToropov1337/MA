# %%
import pandas as pd

# %%
df = pd.read_csv('pydata-book/datasets/bitly_usagov/all_competitors.csv', sep = ',')

# %%
df
# Out:
#           FORMAT             CITY COMPETITOR  \
# 0          HYPER          LIPETSK        5KA
# 1          HYPER          LIPETSK      LENTA
# 2          HYPER         VLADIMIR     GLOBUS
# 3          HYPER         VLADIMIR     MAGNIT
# 4   NASHA RADUGA            PENZA      LENTA
# 5   NASHA RADUGA            PENZA       SPAR
# 6          SUPER  GUS-KHRUSTALNIY     MAGNIT
# 7           АТАК          LAKINSK     MAGNIT
# 8          HYPER          LIPETSK    KARUSEL
# 9           CITY     MAGNITOGORSK        5KA
# 10          CITY     MAGNITOGORSK      LENTA
# 11         HYPER     NOVOKUZNETSK      LENTA
# 12         HYPER     NOVOKUZNETSK     MAGNIT
# 13         SUPER         VLADIMIR        5KA
# 14         SUPER         VLADIMIR        5KA
# 15         SUPER         VLADIMIR        5KA
# 16         HYPER          BARNAUL      LENTA
# 17         HYPER          BARNAUL     YARCHE
#
#                                   ADDRESS COMP FORMAT  ID_COMP ФАЙЛ в отчете  \
# ...

# %%
df2 = pd.read_csv('pydata-book/datasets/bitly_usagov/1wave.csv', sep = ',')

# %%
df2[df2['ADDRESS'].notnull()].head(1)
# Out:
#   СЕГМЕНТ НАЗВАНИЕ СЕГМЕНТА КАТЕГОРИЯ  \
# 0     106          МЯСО П/П       137
#
#                                НАЗВАНИЕ КАТЕГОРИИ СЕМЬЯ      НАЗВАНИЕ СЕМЬИ  \
# 0  ГОВЯДИНА П/П  (в т.ч. ВЕСОВОЙ товар) КРОМЕ СТМ   120  ГОВЯДИНА МРАМОРНАЯ
#
#   Unnamed: 6 FORMAT          CITY COMPETITOR  \
# 0        NaN   CITY  MAGNITOGORSK        5KA
#
#                               ADDRESS COMP FORMAT ID_COMP ID_ZONE  \
# 0  Магнитогорск, ул. Доменщиков, д. 3       SUPER  605118     NaN
#
#   ФАЙЛ в отчете
# 0     МА_файл 1

# %%
df3 = df2[(df2['ADDRESS'] != 'БРЕНД') & (df2['ADDRESS'].notnull())]

# %%
df3.head(1)
# Out:
#   СЕГМЕНТ НАЗВАНИЕ СЕГМЕНТА КАТЕГОРИЯ  \
# 0     106          МЯСО П/П       137
#
#                                НАЗВАНИЕ КАТЕГОРИИ СЕМЬЯ      НАЗВАНИЕ СЕМЬИ  \
# 0  ГОВЯДИНА П/П  (в т.ч. ВЕСОВОЙ товар) КРОМЕ СТМ   120  ГОВЯДИНА МРАМОРНАЯ
#
#   Unnamed: 6 FORMAT          CITY COMPETITOR  \
# 0        NaN   CITY  MAGNITOGORSK        5KA
#
#                               ADDRESS COMP FORMAT ID_COMP ID_ZONE  \
# 0  Магнитогорск, ул. Доменщиков, д. 3       SUPER  605118     NaN
#
#   ФАЙЛ в отчете
# 0     МА_файл 1

# %%
df['ID_COMP'].tolist()
# Out:
# [205008,
#  203032,
#  201003,
#  204012,
#  203074,
#  207007,
#  204055,
#  204091,
#  202023,
#  605118,
#  603047,
#  503038,
#  504014,
#  205146,
#  205084,
#  205147,
#  503029,
#  513001]

# %%
int(df3.loc[6]['ID_COMP']) in df['ID_COMP'].tolist()
# Out:
# True

# %%
r = [ str(i) for i in df['ID_COMP'].tolist()]

# %%
r
# Out:
# ['205008',
#  '203032',
#  '201003',
#  '204012',
#  '203074',
#  '207007',
#  '204055',
#  '204091',
#  '202023',
#  '605118',
#  '603047',
#  '503038',
#  '504014',
#  '205146',
#  '205084',
#  '205147',
#  '503029',
#  '513001']

# %%
df.loc[3]
# Out:
# FORMAT                               HYPER
# CITY                              VLADIMIR
# COMPETITOR                          MAGNIT
# ADDRESS          Владимир, ул. Мира, д. 17
# COMP FORMAT                          SUPER
# ID_COMP                             204012
# ФАЙЛ в отчете                    МА_файл 1
# geo_object_id                        16397
# Name: 3, dtype: object

# %%
df
# Out:
#           FORMAT             CITY COMPETITOR  \
# 0          HYPER          LIPETSK        5KA
# 1          HYPER          LIPETSK      LENTA
# 2          HYPER         VLADIMIR     GLOBUS
# 3          HYPER         VLADIMIR     MAGNIT
# 4   NASHA RADUGA            PENZA      LENTA
# 5   NASHA RADUGA            PENZA       SPAR
# 6          SUPER  GUS-KHRUSTALNIY     MAGNIT
# 7           АТАК          LAKINSK     MAGNIT
# 8          HYPER          LIPETSK    KARUSEL
# 9           CITY     MAGNITOGORSK        5KA
# 10          CITY     MAGNITOGORSK      LENTA
# 11         HYPER     NOVOKUZNETSK      LENTA
# 12         HYPER     NOVOKUZNETSK     MAGNIT
# 13         SUPER         VLADIMIR        5KA
# 14         SUPER         VLADIMIR        5KA
# 15         SUPER         VLADIMIR        5KA
# 16         HYPER          BARNAUL      LENTA
# 17         HYPER          BARNAUL     YARCHE
# 18         HYPER          IZHEVSK      LENTA
# 19         HYPER          IZHEVSK     MAGNIT
# ...

# %%
c = 0
for i in range(len(df3)):
    if str(df3.loc[i]['ID_COMP']) not in r:        
        x = len(df)
        df.loc[x] =''
        df.loc[x] = df3.loc[i]
        r.append(str(df3.loc[i]['ID_COMP']))
        
print(c)
# Out:
# 0

# %%
df
# Out:
#           FORMAT             CITY COMPETITOR  \
# 0          HYPER          LIPETSK        5KA
# 1          HYPER          LIPETSK      LENTA
# 2          HYPER         VLADIMIR     GLOBUS
# 3          HYPER         VLADIMIR     MAGNIT
# 4   NASHA RADUGA            PENZA      LENTA
# 5   NASHA RADUGA            PENZA       SPAR
# 6          SUPER  GUS-KHRUSTALNIY     MAGNIT
# 7           АТАК          LAKINSK     MAGNIT
# 8          HYPER          LIPETSK    KARUSEL
# 9           CITY     MAGNITOGORSK        5KA
# 10          CITY     MAGNITOGORSK      LENTA
# 11         HYPER     NOVOKUZNETSK      LENTA
# 12         HYPER     NOVOKUZNETSK     MAGNIT
# 13         SUPER         VLADIMIR        5KA
# 14         SUPER         VLADIMIR        5KA
# 15         SUPER         VLADIMIR        5KA
# 16         HYPER          BARNAUL      LENTA
# 17         HYPER          BARNAUL     YARCHE
# 18         HYPER          IZHEVSK      LENTA
# 19         HYPER          IZHEVSK     MAGNIT
# ...

# %%
df.fillna(0)
# Out:
#           FORMAT             CITY COMPETITOR  \
# 0          HYPER          LIPETSK        5KA
# 1          HYPER          LIPETSK      LENTA
# 2          HYPER         VLADIMIR     GLOBUS
# 3          HYPER         VLADIMIR     MAGNIT
# 4   NASHA RADUGA            PENZA      LENTA
# 5   NASHA RADUGA            PENZA       SPAR
# 6          SUPER  GUS-KHRUSTALNIY     MAGNIT
# 7           АТАК          LAKINSK     MAGNIT
# 8          HYPER          LIPETSK    KARUSEL
# 9           CITY     MAGNITOGORSK        5KA
# 10          CITY     MAGNITOGORSK      LENTA
# 11         HYPER     NOVOKUZNETSK      LENTA
# 12         HYPER     NOVOKUZNETSK     MAGNIT
# 13         SUPER         VLADIMIR        5KA
# 14         SUPER         VLADIMIR        5KA
# 15         SUPER         VLADIMIR        5KA
# 16         HYPER          BARNAUL      LENTA
# 17         HYPER          BARNAUL     YARCHE
# 18         HYPER          IZHEVSK      LENTA
# 19         HYPER          IZHEVSK     MAGNIT
# ...

# %%
df = df.fillna(0)

# %%
df.to_csv('pydata-book/datasets/bitly_usagov/lol.csv', index=False)

# %%
qq = pd.read_csv('pydata-book/datasets/bitly_usagov/lol.csv', sep = ',')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-f0d7b9a10efc> in <module>()
# ----> 1 qq = pd.read_csv('pydata-book/datasets/bitly_usagov/lol.csv', sep = ',')
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
# c = 0
# for i in range(len(df3)):
#     if str(df3.loc[i]['ID_COMP']) not in r:        
#         x = len(df)
#         df.loc[x] =''
#         df.loc[x]['FORMAT'] = df3.loc[i]['FORMAT']
#         df.loc[x]['CITY'] = df3.loc[i]['CITY']
#         df.loc[x]['COMPETITOR'] = df3.loc[i]['COMPETITOR']
#         df.loc[x]['ADDRESS'] = df3.loc[i]['ADDRESS']
#         df.loc[x]['COMP FORMAT'] = df3.loc[i]['COMP FORMAT']
#         df.loc[x]['ID_COMP'] = df3.loc[i]['ID_COMP']
#         df.loc[x]['ФАЙЛ в отчете'] = df3.loc[i]['ФАЙЛ в отчете']
#         r.append(str(df3.loc[i]['ID_COMP']))
        
# print(c)
# Out:
# 0
