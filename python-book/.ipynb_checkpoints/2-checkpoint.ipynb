# %%
import pandas as pd

# %%
df = pd.read_csv('pydata-book/datasets/bitly_usagov/all_competitors.csv', sep = ',')

# %%
df2 = pd.read_csv('pydata-book/datasets/bitly_usagov/1wave.csv', sep = ',')

# %%
df2['store_id'] = ''

# %%
r = df[['ADDRESS','geo_object_id']]

# %%
for i in range(39):
    for j in range(len(r)):
        if str(df2.loc[i]['ADDRESS']).strip() == str(r.loc[j]['ADDRESS']).strip():
            df2.loc[i]['store_id'] = int(r.loc[j]['geo_object_id'])

# %%
df
# Out:
#           FORMAT             CITY COMPETITOR  \
# 0          HYPER          LIPETSK        5KA
# 1          HYPER          LIPETSK      LENTA
# 2          HYPER         VLADIMIR     GLOBUS
# 3          HYPER         VLADIMIR     MAGNIT
# 4   NASHA RADUGA            PENZA      LENTA
# 5   NASHA RADUGA            PENZA       SPAR
# 6          SUPER  GUS-KHRUSTALNIY     MAGNIT
# 7           АТАК          LAKINSK     MAGNIT
# 8          HYPER          LIPETSK    KARUSEL
# 9           CITY     MAGNITOGORSK        5KA
# 10          CITY     MAGNITOGORSK      LENTA
# 11         HYPER     NOVOKUZNETSK      LENTA
# 12         HYPER     NOVOKUZNETSK     MAGNIT
# 13         SUPER         VLADIMIR        5KA
# 14         SUPER         VLADIMIR        5KA
# 15         SUPER         VLADIMIR        5KA
# 16         HYPER          BARNAUL      LENTA
# 17         HYPER          BARNAUL     YARCHE
#
#                                   ADDRESS COMP FORMAT  ID_COMP ФАЙЛ в отчете  \
# ...

# %%
df2['store_id']
# Out:
# 0        1183
# 1         281
# 2         194
# 3
# 4
# 5
# 6       16382
# 7         895
# 8         215
# 9       13103
# 10        238
# 11       1297
# 12      16398
# 13        894
# 14
# 15
# 16      11189
# 17
# 18
# 19
# 20
# 21      13136
# 22       4988
# 23
# 24       2487
# 25
# 26
# 27
# 28
# 29
#         ...
# 2871
# 2872
# 2873
# 2874
# 2875
# 2876
# 2877
# 2878
# 2879
# 2880
# 2881
# 2882
# 2883
# 2884
# 2885
# 2886
# 2887
# 2888
# 2889
# 2890
# 2891
# 2892
# 2893
# 2894
# 2895
# 2896
# 2897
# 2898
# 2899
# 2900
# Name: store_id, Length: 2901, dtype: object

# %%
df3 = pd.read_csv('pydata-book/datasets/bitly_usagov/1wave.csv', sep = ',')

# %%
df2.drop(['Unnamed: 6'],axis=1)
# Out:
#                                                 СЕГМЕНТ  \
# 0                                                   106
# 1                                                   106
# 2                                                   106
# 3                                                   106
# 4                                                   106
# 5                                                   115
# 6                                                   106
# 7                                                   106
# 8                                                   106
# 9                                                   106
# 10                                                  106
# 11                                                  106
# 12                                                  106
# 13                                                  106
# 14                                                  106
# 15                                                  106
# ...

# %%
df2 = df2[df2['store_id'] != '']

# %%
df2.drop(['Unnamed: 6'],axis=1)
# Out:
#    СЕГМЕНТ НАЗВАНИЕ СЕГМЕНТА КАТЕГОРИЯ  \
# 0      106          МЯСО П/П       137
# 1      106          МЯСО П/П       137
# 2      106          МЯСО П/П       137
# 6      106          МЯСО П/П       137
# 7      106          МЯСО П/П       137
# 8      106          МЯСО П/П       139
# 9      106          МЯСО П/П       139
# 10     106          МЯСО П/П       139
# 11     106          МЯСО П/П       139
# 12     106          МЯСО П/П       139
# 13     106          МЯСО П/П       140
# 16     106          МЯСО П/П       140
# 21     106          МЯСО П/П       142
# 22     106          МЯСО П/П       142
# 24     106          МЯСО П/П       142
# 36     106          МЯСО П/П       146
#
#                                 НАЗВАНИЕ КАТЕГОРИИ СЕМЬЯ       НАЗВАНИЕ СЕМЬИ  \
# 0   ГОВЯДИНА П/П  (в т.ч. ВЕСОВОЙ товар) КРОМЕ СТМ   120   ГОВЯДИНА МРАМОРНАЯ
# 1   ГОВЯДИНА П/П  (в т.ч. ВЕСОВОЙ товар) КРОМЕ СТМ   130      ГОВЯДИНА ХАЛЯЛЬ
# ...

# %%
df2 = df2.drop(['Unnamed: 6'],axis=1)

# %%
df2
# Out:
#    СЕГМЕНТ НАЗВАНИЕ СЕГМЕНТА КАТЕГОРИЯ  \
# 0      106          МЯСО П/П       137
# 1      106          МЯСО П/П       137
# 2      106          МЯСО П/П       137
# 6      106          МЯСО П/П       137
# 7      106          МЯСО П/П       137
# 8      106          МЯСО П/П       139
# 9      106          МЯСО П/П       139
# 10     106          МЯСО П/П       139
# 11     106          МЯСО П/П       139
# 12     106          МЯСО П/П       139
# 13     106          МЯСО П/П       140
# 16     106          МЯСО П/П       140
# 21     106          МЯСО П/П       142
# 22     106          МЯСО П/П       142
# 24     106          МЯСО П/П       142
# 36     106          МЯСО П/П       146
#
#                                 НАЗВАНИЕ КАТЕГОРИИ СЕМЬЯ       НАЗВАНИЕ СЕМЬИ  \
# 0   ГОВЯДИНА П/П  (в т.ч. ВЕСОВОЙ товар) КРОМЕ СТМ   120   ГОВЯДИНА МРАМОРНАЯ
# 1   ГОВЯДИНА П/П  (в т.ч. ВЕСОВОЙ товар) КРОМЕ СТМ   130      ГОВЯДИНА ХАЛЯЛЬ
# ...

# %%
df2.to_csv('pydata-book/datasets/bitly_usagov/with_ids.csv', sep=',')

# %%
df2
# Out:
#                                                 СЕГМЕНТ  \
# 0                                                   106
# 1                                                   106
# 2                                                   106
# 3                                                   106
# 4                                                   106
# 5                                                   115
# 6                                                   106
# 7                                                   106
# 8                                                   106
# 9                                                   106
# 10                                                  106
# 11                                                  106
# 12                                                  106
# 13                                                  106
# 14                                                  106
# 15                                                  106
# ...

# %%
df4 = pd.read_csv('pydata-book/datasets/bitly_usagov/with_ids.csv', sep = ',',dtype = {'store_id': int})

# %%
df4
# Out:
#     Unnamed: 0  СЕГМЕНТ НАЗВАНИЕ СЕГМЕНТА  КАТЕГОРИЯ  \
# 0            0      106          МЯСО П/П        137
# 1            1      106          МЯСО П/П        137
# 2            2      106          МЯСО П/П        137
# 3            6      106          МЯСО П/П        137
# 4            7      106          МЯСО П/П        137
# 5            8      106          МЯСО П/П        139
# 6            9      106          МЯСО П/П        139
# 7           10      106          МЯСО П/П        139
# 8           11      106          МЯСО П/П        139
# 9           12      106          МЯСО П/П        139
# 10          13      106          МЯСО П/П        140
# 11          16      106          МЯСО П/П        140
# 12          21      106          МЯСО П/П        142
# 13          22      106          МЯСО П/П        142
# 14          24      106          МЯСО П/П        142
# 15          36      106          МЯСО П/П        146
#
# ...

# %%
df4.shape[0]
# Out:
# 16
