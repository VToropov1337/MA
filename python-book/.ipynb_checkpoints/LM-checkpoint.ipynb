# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 200)

# %%
df = pd.read_csv('116.csv', sep=';')

# %%
df223 = df[df['id'] == 223]

# %%
df223[(df223['report_1_id'] == 2863343)]
# Out:
#       report_1_id  report_2_id  r2_state       barcode  mark_id  \
# 2122      2863343      2863568  accepted  4.607084e+12        1
# 2123      2863343      2863569  accepted  8.436024e+12        2
# 2124      2863343      2863570  accepted  8.410179e+12        3
# 2125      2863343      2863571  accepted  8.428917e+12        4
# 2126      2863343      2863572  accepted  8.424537e+12        5
# 2127      2863343      2863573  accepted  4.650058e+12        6
# 2128      2863343      2863574  accepted  8.410179e+12        7
# 2129      2863343      2863575  accepted  8.420701e+12        8
# 2130      2863343      2863576  accepted  1.000034e+12        9
# 2131      2863343      2863577  accepted  8.410180e+12       10
# 2132      2863343      2863578  accepted  8.410179e+12       11
# 2133      2863343      2863579  accepted  8.420701e+12       12
# 2134      2863343      2863580  accepted  4.607015e+12       13
# 2135      2863343      2863581  accepted  4.607015e+12       14
# ...
